# %% [markdown]
# ##Step 3: Run Data Pipeline

# %%
# %matplotlib qt

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import exec.data_framework.data_pipeline as dtp
from exec.utilgen import viewdf

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ###Training Set 1

# %%
version = 2
dataTrainPath = os.path.join('data', 'data_derived', 'train1.csv')
dataTrain = pd.read_csv(dataTrainPath, index_col=0)
display(dataTrain.sample(n=10))
display(dataTrain.describe())
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Name</th>
#       <th>Sex</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Ticket</th>
#       <th>Fare</th>
#       <th>Cabin</th>
#       <th>Embarked</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>519</th>
#       <td>1</td>
#       <td>2</td>
# ...

# %%
dataClean = dtp.featuresPipeline(dataTrain, version=version)
display(dataClean.sample(n=10))
display(dataClean.describe())
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Survived</th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>EmbarkedC</th>
#       <th>EmbarkedS</th>
#       <th>Female</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>226</th>
#       <td>0</td>
#       <td>3</td>
#       <td>22.00</td>
#       <td>0</td>
#       <td>0</td>
#       <td>9.3500</td>
# ...

# %%
dataTrainCleanPath = os.path.join('data','data_derived','train1c.csv')
dataClean.to_csv(dataTrainCleanPath, index=False)

# %% [markdown]
# ###Training Set 2

# %%
dataTestPath = os.path.join('data','data_derived','train2.csv')
dataTestCleanPath = os.path.join('data','data_derived','train2c.csv')
dataTest = pd.read_csv(dataTestPath, index_col=0)
dataTestClean = dtp.featuresPipeline(dataTest, version=version)
dataTestClean.to_csv(dataTestCleanPath, index=False)
display(dataTestClean.drop(columns=['Survived']).sample(n=10))
display(dataTestClean.describe())
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Pclass</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#       <th>EmbarkedC</th>
#       <th>EmbarkedS</th>
#       <th>Female</th>
#     </tr>
#     <tr>
#       <th>PassengerId</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>44</th>
#       <td>2</td>
#       <td>3.000000</td>
#       <td>1</td>
#       <td>2</td>
#       <td>41.5792</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
# ...
